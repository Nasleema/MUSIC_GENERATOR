# %% [markdown]
# <a href="https://colab.research.google.com/github/Nasleema/MUSIC_GENERATOR/blob/main/MusicGeneration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U torch torchaudio --index - url http://download.pytorch.org/
# !pip install torch torchaudio transformers datasets accelerate
# !pip install audiocraft

# %%
# !pip install -U torch torchaudio transformers  accelerate scipy

# %%
import torch
from transformers import MusicgenForConditionalGeneration, AutoProcessor

device = "cuda" if torch.cuda.is_available() else "cpu"
processor = AutoProcessor.from_pretrained("facebook/musicgen-small")
model = MusicgenForConditionalGeneration.from_pretrained("facebook/musicgen-small").to(device)

# %%
prompt = ["lofi chill beat with soft piano and rain"]

input = processor(text=prompt, padding=True, return_tensors="pt").to(device)

# %%
audio_values = model.generate(**input,max_new_tokens=512)

import scipy.io.wavfile
scipy.io.wavfile.write("output.wav",rate=32000,data=audio_values[0, 0].cpu().numpy())
